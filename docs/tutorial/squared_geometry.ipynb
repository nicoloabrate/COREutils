# %%
# import modules
import sys
import os
import numpy as np
import serpentTools
from matplotlib import rc
# add "coremap" directories to path
coremapath = 'C:\\Users\\39346\\Documents\\mycodes'
sys.path.append(coremapath)
import coreutils.coremap.CoreMap as cm
import matplotlib as mpl
mpl.rcParams['figure.dpi']= 200  # set dpi for increasing plot rendering quality

# rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
# for Palatino and other serif fonts use:
rc('font', **{'family': 'sans-serif', 'sans-serif': ['Arial']})

# input file name and location
fname = 'uam_1_8.txt'

# define geometrical parameters
L = 21.42  # pitch [cm]
rotangle = 45  # rotation angle [degree]

# instance initialisation
core = cm(fname, rotangle, L)

PWR_colors = ['deepskyblue', 'white', 'forestgreen', 'gold', 'lightgray']
coretype = [0, 1, 2, 3, 4]
corelabel = ['0', '1', '2', '3', '4']
asscol = dict(zip(coretype, PWR_colors))
asslabel = dict(zip(coretype, corelabel))

# Do you want to plot the geometry without any label?
core.plot(fill=True, label=True, dictname=asslabel)
# Out:
# C:\Users\39346\Documents\mycodes\coreutils\coremap\CoreMap.py:580: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   fill=fill, **kwargs)
