# %%
# import external modules
import sys
import os
import numpy as np
import serpentTools
from matplotlib import rc
# add "coreutils" directories to path
sys.path.append(os.path.abspath('../../../../../'))
from coreutils.core.Core import Core
from coreutils.core.plot import RadialPlot, AxialPlot
import matplotlib as mpl
mpl.rcParams['figure.dpi']= 200  # set dpi for increasing plot rendering quality

rc('font', **{'family': 'sans-serif', 'sans-serif': ['Arial']})
rc('text', usetex=True)

# input file name and location
try:
    os.chdir("EBR-II")
except FileNotFoundError:
    pass

filepath = os.path.join("input.json")
ebrII = Core(filepath)

# %%
RadialPlot(ebrII, label=True, fren=True, fontsize=3.5)
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %%
asslabel = ebrII.assemblytypes
RadialPlot(ebrII, label=True, fren=True, fontsize=3, dictname=asslabel)
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
